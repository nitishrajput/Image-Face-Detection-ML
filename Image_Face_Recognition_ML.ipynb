# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishrajput/Image-Face-Recognition-ML/blob/main/Image_Face_Recognition_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
imagePath = "IMG-20210808-WA0010.jpg"
# Create the haar cascade
#faceCascade = cv2.CascadeClassifier(cascPath)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

print ("Found {0} faces!".format(len(faces)))

import matplotlib.pyplot as plt
import matplotlib.patches as ptch
# load image using cv2....and do processing.
print("plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
print("plt.show()")
plt.show()

figure, ax = plt.subplots(1)
for (x, y, w, h) in faces:
    rect = ptch.Rectangle((x,y),w,h, edgecolor='g', facecolor="none")
    ax.imshow(image)
    ax.add_patch(rect)
cv2.waitKey(0)
# Out:
# Found 3 faces!
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.show()
# -1
